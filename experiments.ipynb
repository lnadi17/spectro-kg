# %%
from speclib import *

# %%
eps = None
audio_base_path = 'audio/'
audio_file_name = 'hawking01.wav'

# %%
fs, audio_data = read_wav_audio(audio_base_path + audio_file_name)

mat = get_matrix(audio_data, eps=eps)
hist = np.histogram(mat, bins=1000)

fig = plt.figure(figsize=(10, 5))
ax1, ax2 = fig.subplots(1, 2)

ax1.plot(hist[1][:-1], hist[0])
spectrogram_show(audio_data, ax2, fs, eps=eps, colorbar=True)
# Out:
# Audio length: 21.18 seconds, Sample rate: 11025 Hz
